# %% [markdown]
# # Beat Tracking

# %% [markdown]
# ## Imports

# %%
import os
import librosa
import librosa.display
import IPython.display as ipd
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ## Loading the files

# %%
path_data = '../ballroom-data/'

# For now just testing with one, expand later
audio_file = path_data+'Media-106001.wav'
ipd.display(ipd.Audio(os.path.join(audio_file)))

# Load audio
x, sr = librosa.load(os.path.join(audio_file))

# Plot audio
t1 = np.arange(x.shape[0]) / sr
plt.figure(figsize=(10, 2))
plt.plot(t1, x, color='gray')
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
plt.xlim([t1[0], t1[-1]])
plt.tight_layout()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Onset Detection

# %% [markdown]
# ## IOI Histogram

# %% [markdown]
# ## Periodicity function

# %% [markdown]
# ## Prediction

# %% [markdown]
# ## Results
